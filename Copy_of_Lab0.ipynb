# %% [markdown]
# <a href="https://colab.research.google.com/github/Francofus/IMSE441/blob/main/Copy_of_Lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab 0**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
Dam=pd.read_csv('/content/drive/MyDrive/IMSE_441/Dams-2023.csv')
Dam
# Out:
#                     Dam_Name  Latitude  Longitude   NID_ID  \
# 0              ELK RIVER DAM   35.2981   -86.0970  TN05101
# 1         TREMAINE RESERVOIR   34.7599  -111.2174  AZ00089
# 2                      BEALE   39.1083  -121.3366  CA10115
# 3                BLACKWELDER   39.1583  -121.3833  CA10116
# 4                     MILLER   39.1699  -121.3966  CA10119
# ...                      ...       ...        ...      ...
# 74091           MEADOW CREEK   39.8066  -107.5472  CO00695
# 74092  HEART LAKE NORTH DIKE   39.7749  -107.3200  CO02889
# 74093   LITTLE HELL'S CANYON   35.0813  -112.4055  AZ00215
# 74094            BEAVER PARK   37.5961  -106.6666  CO00763
# 74095              LYNX LAKE   34.5225  -112.3863  AZ00049
#
#                                   Primary_Purpose State  Year_Completed  \
# 0                                   Flood Control    TN            1952
# 1                                      Irrigation    AZ            1952
# ...

# %%
Dam['Latitude'].describe()
# Out:
# count    73999.000000
# mean        38.535344
# std          4.951658
# min         13.360500
# 25%         34.500000
# 50%         38.986600
# 75%         41.976600
# max         71.266600
# Name: Latitude, dtype: float64

# %%
Dam['Longitude'].describe()
# Out:
# count    74001.000000
# mean       -93.484288
# std         11.897321
# min       -176.687300
# 25%        -99.064700
# 50%        -94.650000
# 75%        -84.989400
# max        -65.672000
# Name: Longitude, dtype: float64

# %%
Dam['Dam_Height'].describe()
# Out:
# count    68294.000000
# mean        28.991127
# std         26.139245
# min          0.000000
# 25%         18.000000
# 50%         25.000000
# 75%         32.000000
# max        770.000000
# Name: Dam_Height, dtype: float64
